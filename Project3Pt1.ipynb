# %%
import pandas as pd
import numpy as np

# %%
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %% [markdown]
# # Basics Preprocessing

# %%
basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9823607  tt9916848  tvEpisode              Episode #3.17
# 9823608  tt9916850  tvEpisode              Episode #3.19
# 9823609  tt9916852  tvEpisode              Episode #3.20
# 9823610  tt9916856      short                   The Wind
# 9823611  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# ...

# %%
basics.replace({'\\N':np.nan}, inplace = True)

# %%
basics.dropna(subset=['runtimeMinutes'], inplace = True)

# %%
basics
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9823562  tt9916754      movie  Chico Albuquerque - Revelações
# 9823568  tt9916766  tvEpisode                  Episode #10.15
# 9823603  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9823610  tt9916856      short                        The Wind
# 9823611  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult startYear endYear  \
# 0                            Carmencita       0      1894     NaN
# 1                Le clown et ses chiens       0      1892     NaN
# ...

# %%
basics.dropna(subset=['genres'], inplace = True)

# %%
basics
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9823562  tt9916754      movie  Chico Albuquerque - Revelações
# 9823568  tt9916766  tvEpisode                  Episode #10.15
# 9823603  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9823610  tt9916856      short                        The Wind
# 9823611  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult startYear endYear  \
# 0                            Carmencita       0      1894     NaN
# 1                Le clown et ses chiens       0      1892     NaN
# ...

# %%
basics_movie = basics[~(basics['titleType'] == 'movie')].index
basics.drop(basics_movie, inplace = True)

# %%
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9823378  tt9916362     movie
# 9823462  tt9916538     movie
# 9823503  tt9916622     movie
# 9823530  tt9916680     movie
# 9823562  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9823378                                              Coven
# 9823462                                Kuambil Lagi Hatiku
# 9823503        Rodolpho Teóphilo - O Legado de um Pioneiro
# ...

# %%
basics['startYear'].dtypes
# Out:
# dtype('O')

# %%
basics['startYear'].value_counts().sort_values().head(20)
# Out:
# 1894      1
# 1899      1
# 1904      1
# 2026      1
# 1896      1
# 1897      1
# 1908      2
# 1903      2
# 1900      2
# 2029      2
# 1906      2
# 1905      3
# 1907      3
# 1909      4
# 2025     12
# 1910     14
# 1911     21
# 1912     44
# 2024     65
# 1913    109
# Name: startYear, dtype: int64

# %%
basics['startYear'] = basics['startYear'].astype(float)

# %%
basics_years = basics[(basics['startYear'] < 2000) | (basics['startYear'] > 2022)].index
basics.drop(basics_years, inplace = True)

# %%
basics
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 76059    tt0077684     movie
# ...            ...       ...
# 9823378  tt9916362     movie
# 9823462  tt9916538     movie
# 9823503  tt9916622     movie
# 9823530  tt9916680     movie
# 9823562  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 76059                    Histórias de Combóios em Portugal
# ...                                                    ...
# 9823378                                              Coven
# 9823462                                Kuambil Lagi Hatiku
# 9823503        Rodolpho Teóphilo - O Legado de um Pioneiro
# ...

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 77964    tt0079644     movie
# 78451    tt0080155     movie
# ...            ...       ...
# 9823285  tt9916170     movie
# 9823294  tt9916190     movie
# 9823333  tt9916270     movie
# 9823378  tt9916362     movie
# 9823462  tt9916538     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 77964                                        November 1828
# 78451                                  The Wonderful Years
# ...                                                    ...
# 9823285                                      The Rehearsal
# 9823294                                          Safeguard
# 9823333                           Il talento del calabrone
# ...

# %% [markdown]
# # Akas

# %%
akas.replace({'\\N':np.nan}, inplace = True)

# %%
akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 35794720  tt9916852         5             Episódio #3.20     PT       pt
# 35794721  tt9916852         6             Episodio #3.20     IT       it
# 35794722  tt9916852         7               एपिसोड #3.20     IN       hi
# 35794723  tt9916856         1                   The Wind     DE      NaN
# 35794724  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# ...

# %%
akas.dropna(subset=['region'], inplace = True)

# %%
# Exclude movies that are included in the documentary category.
akas_us = akas['region'].str.contains('US',case=False)
akas = akas[akas_us]

# %%
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35794251  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35794321  tt9916620         1                          The Copeland Case
# 35794410  tt9916702         1              Loving London: The Playground
# 35794453  tt9916756         1                   Pretty Pretty Black Girl
# 35794469  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# ...

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1434625 entries, 5 to 35794469
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1434625 non-null  object
#  1   ordering         1434625 non-null  int64
#  2   title            1434625 non-null  object
#  3   region           1434625 non-null  object
#  4   language         3905 non-null     object
#  5   types            978439 non-null   object
#  6   attributes       46518 non-null    object
#  7   isOriginalTitle  1433280 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 98.5+ MB

# %% [markdown]
# # Basics in US

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34803       True
# 61116       True
# 67669       True
# 77964      False
# 78451      False
#            ...
# 9823285     True
# 9823294     True
# 9823333    False
# 9823378     True
# 9823462    False
# Name: tconst, Length: 152143, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9822750  tt9914942     movie
# 9823145  tt9915872     movie
# 9823285  tt9916170     movie
# 9823294  tt9916190     movie
# 9823378  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9822750                             Life Without Sara Amat
# 9823145                               The Last White Witch
# 9823285                                      The Rehearsal
# ...

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89149 entries, 34803 to 9823378
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          89149 non-null  object
#  1   titleType       89149 non-null  object
#  2   primaryTitle    89149 non-null  object
#  3   originalTitle   89149 non-null  object
#  4   isAdult         89149 non-null  object
#  5   startYear       86611 non-null  float64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  89149 non-null  object
#  8   genres          89149 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 6.8+ MB

# %% [markdown]
# # Ratings

# %%
ratings.replace({'\\N':np.nan}, inplace = True)

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1967
# 1        tt0000002            5.8       264
# 2        tt0000003            6.5      1811
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2610
# ...            ...            ...       ...
# 1306788  tt9916730            8.3        10
# 1306789  tt9916766            7.0        21
# 1306790  tt9916778            7.2        36
# 1306791  tt9916840            8.8         6
# 1306792  tt9916880            8.2         6
#
# [1306793 rows x 3 columns]

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers_ratings =ratings['tconst'].isin(akas['titleId'])
keepers_ratings
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1306788    False
# 1306789    False
# 1306790    False
# 1306791    False
# 1306792    False
# Name: tconst, Length: 1306793, dtype: bool

# %%
ratings = ratings[keepers_ratings]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1967
# 1        tt0000002            5.8       264
# 4        tt0000005            6.2      2610
# 5        tt0000006            5.2       181
# 6        tt0000007            5.4       816
# ...            ...            ...       ...
# 1306754  tt9916200            8.1       229
# 1306755  tt9916204            8.1       262
# 1306762  tt9916348            8.3        18
# 1306763  tt9916362            6.4      5312
# 1306768  tt9916428            3.8        14
#
# [497338 rows x 3 columns]

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497338 entries, 0 to 1306768
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         497338 non-null  object
#  1   averageRating  497338 non-null  float64
#  2   numVotes       497338 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.2+ MB

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['.ipynb_checkpoints',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz']

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1967
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2610
# 3  tt0000006            5.2       181
# 4  tt0000007            5.4       816

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89149 entries, 0 to 89148
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          89149 non-null  object
#  1   titleType       89149 non-null  object
#  2   primaryTitle    89149 non-null  object
#  3   originalTitle   89149 non-null  object
#  4   isAdult         89149 non-null  int64
#  5   startYear       86611 non-null  float64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  89149 non-null  int64
#  8   genres          89149 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 6.1+ MB
