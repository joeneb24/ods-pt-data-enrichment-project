# %%
import pandas as pd
import numpy as np

# %%
final2000 = pd.read_csv('Data/final_tmdb_data_2000.0.csv.gz')
final2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
final2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1236 non-null   object
#  1   adult                  1235 non-null   float64
#  2   backdrop_path          680 non-null    object
#  3   belongs_to_collection  113 non-null    object
#  4   budget                 1235 non-null   float64
#  5   genres                 1235 non-null   object
#  6   homepage               64 non-null     object
#  7   id                     1235 non-null   float64
#  8   original_language      1235 non-null   object
#  9   original_title         1235 non-null   object
#  10  overview               1213 non-null   object
#  11  popularity             1235 non-null   float64
#  12  poster_path            1113 non-null   object
#  13  production_companies   1235 non-null   object
# ...

# %%
final2001 = pd.read_csv('Data/final_tmdb_data_2001.0.csv.gz')
final2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
#
# ...

# %%
final2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1331 entries, 0 to 1330
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1331 non-null   object
#  1   adult                  1330 non-null   float64
#  2   backdrop_path          714 non-null    object
#  3   belongs_to_collection  93 non-null     object
#  4   budget                 1330 non-null   float64
#  5   genres                 1330 non-null   object
#  6   homepage               109 non-null    object
#  7   id                     1330 non-null   float64
#  8   original_language      1330 non-null   object
#  9   original_title         1330 non-null   object
#  10  overview               1301 non-null   object
#  11  popularity             1330 non-null   float64
#  12  poster_path            1195 non-null   object
#  13  production_companies   1330 non-null   object
# ...

# %%
tmdbresults2000_2001 = pd.concat([final2001, final2001], axis=0)

# %%
tmdbresults2000_2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2662 entries, 0 to 1330
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2662 non-null   object
#  1   adult                  2660 non-null   float64
#  2   backdrop_path          1428 non-null   object
#  3   belongs_to_collection  186 non-null    object
#  4   budget                 2660 non-null   float64
#  5   genres                 2660 non-null   object
#  6   homepage               218 non-null    object
#  7   id                     2660 non-null   float64
#  8   original_language      2660 non-null   object
#  9   original_title         2660 non-null   object
#  10  overview               2602 non-null   object
#  11  popularity             2660 non-null   float64
#  12  poster_path            2390 non-null   object
#  13  production_companies   2660 non-null   object
# ...

# %%
tmdbresults2000_2001
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2     tt0114447    0.0                               NaN
# 3     tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4     tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# ...         ...    ...                               ...
# 1326  tt7797670    0.0                               NaN
# 1327  tt7797790    0.0                               NaN
# 1328  tt8665056    0.0                               NaN
# 1329  tt8795764    0.0                               NaN
# 1330  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN  22000000.0
# ...

# %%
## Save current dataframe to file.
tmdbresults2000_2001.to_csv("Data/tmdb_results_combined.csv.gz",compression='gzip',index=False)

# %%
final_df = pd.read_csv('Data/tmdb_results_combined.csv.gz')
final_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2     tt0114447    0.0                               NaN
# 3     tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4     tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# ...         ...    ...                               ...
# 2657  tt7797670    0.0                               NaN
# 2658  tt7797790    0.0                               NaN
# 2659  tt8665056    0.0                               NaN
# 2660  tt8795764    0.0                               NaN
# 2661  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN  22000000.0
# ...

# %%
has_financial_info = final_df.loc[(final_df['budget'] > 0) | (final_df['revenue'] > 0)]

# %%
has_financial_info
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 4     tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# 5     tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg
# 6     tt0119004    0.0  /7xrlSPGDO4CDT6IHTctDlkYxTzw.jpg
# 9     tt0120681    0.0  /xo2S7gRwCvWdVqM0Swv37yA2rzw.jpg
# ...         ...    ...                               ...
# 2594  tt0445841    0.0  /lO3XAxV38SC7ZuuNVdy6E6nOZac.jpg
# 2610  tt0867181    0.0                               NaN
# 2612  tt1039952    0.0  /yTGmGjAd0gfpVK0ezoqWgx7AJkp.jpg
# 2627  tt1764172    0.0                               NaN
# 2640  tt2957918    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 1                      NaN  48000000.0
# 4                      NaN  22000000.0
# 5                      NaN   1000000.0
# 6                      NaN         0.0
# 9                      NaN  35000000.0
# ...

# %%
has_financial_info['certification'].value_counts()
# Out:
# R        244
# PG-13    140
# PG        36
# NR        14
# G         12
# Name: certification, dtype: int64

# %%
has_financial_info.groupby(['certification'])['revenue'].mean()
# Out:
# certification
# G        1.482838e+08
# NR       8.758989e+06
# PG       1.400335e+08
# PG-13    9.689602e+07
# R        3.436071e+07
# Name: revenue, dtype: float64

# %%
has_financial_info.groupby(['certification'])['budget'].mean()
# Out:
# certification
# G        3.533333e+07
# NR       2.400000e+06
# PG       4.161651e+07
# PG-13    4.066297e+07
# R        2.060131e+07
# Name: budget, dtype: float64
